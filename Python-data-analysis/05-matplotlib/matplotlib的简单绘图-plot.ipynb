# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
a = [1,2,3]
plt.plot(a)
plt.show()  # x取index的值 0 1 2

# %%
a = [1, 2, 3]
b = [4, 5, 6]
plt.plot(a, b)

# %%
# %matplotlib inline

# %%
plt.plot(a, b) # 上面的魔法函数，不用show

# %%
# %timeit np.arange(10)
# Out:
# 598 ns ± 6.02 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
plt.plot(a, b, '--')  # shift + tab 查看参数

# %%
c = [10,8,6]
d = [1,8,3]
plt.plot(a,b, 'r--', c,d, 'b*')
# Out:
# [<matplotlib.lines.Line2D at 0x1a49b09f9d0>,
#  <matplotlib.lines.Line2D at 0x1a49b09fa30>]

# %%
t = np.arange(0.0, 2.0, 0.1)

# %%
t.size
# Out:
# 20

# %%
s = np.sin(t*np.pi)

# %%
s.size
# Out:
# 20

# %%
plt.plot(t,s,'r--',label='aaaa')
plt.plot(t*2, s, 'b--', label='bbbb')
plt.xlabel('this is x')
plt.ylabel('this is y')
plt.title('this is a demo')
plt.legend()
